# %%
# using CREMP data from portal here:
# https://geodata.myfwc.com/datasets/myfwc::coral-reef-evaluation-and-monitoring-project-cremp-locations/explore?location=24.846222%2C-80.748910%2C8.43
# 
# NOTE: can also pull JSON from here https://geodata.myfwc.com/datasets/02659342308142349932ab101c1d8a6b_14/api

import pandas

FILEPATH = "../data/Coral_Reef_Evaluation_and_Monitoring_Project_(CREMP)_Locations.csv"

# read the tab-separated-values file (`.raw` = `.tsv`)
cremp_df = pandas.read_csv(
    FILEPATH, 
)

# now you can use the pandas dataframe
SEPARATOR = "="*100  # this creates big string like `=====================` with 100 `=` characters

display(cremp_df.head())
display(SEPARATOR)
display(cremp_df.describe())
display(SEPARATOR)
display(cremp_df.info())
display(SEPARATOR)
display(cremp_df)
# Out:
#            X          Y  OBJECTID ProjectRegion Site_Code  siteid habitatid  \
# 0 -80.347497  25.173595       312         FKNMS       9H1      10        HB
# 1 -80.347497  25.173595       313         FKNMS       9H1      10        HB
# 2 -80.347497  25.173595       314         FKNMS       9H1      10        HB
# 3 -80.347497  25.173595       315         FKNMS       9H1      10        HB
# 4 -80.378197  25.120095       316         FKNMS       9H2      11        HB
#
#       sitename  stationid subRegionId  length  offshoreDepth    latDD    lonDD
# 0  Rattlesnake        101          UK      23              6  25.1736 -80.3475
# 1  Rattlesnake        102          UK      22              6  25.1736 -80.3475
# 2  Rattlesnake        103          UK      23              6  25.1736 -80.3475
# 3  Rattlesnake        104          UK      25              6  25.1736 -80.3475
# 4   El Radabob        111          UK      22              9  25.1201 -80.3782
# ...

# %%
# for number in [1,3,3]:
#     display(number + 1)

# display(cremp_df['offshoreDepth'])
# for value in cremp_df['offshoreDepth']:
#     print(value, end=',')

# display(cremp_df.hist())

cremp_df.plot.scatter('OBJECTID', 'offshoreDepth')
# Out:
# 6,6,6,6,9,9,9,9,8,8,8,8,12,12,12,12,12,12,12,12,14,14,14,14,18,18,18,18,8,9,7,8,15,17,15,16,20,22,22,22,20,20,21,18,21,18,18,18,22,23,22,23,13,18,23,22,15,14,16,17,6,4,5,3,22,22,24,22,14,15,17,21,23,25,24,22,34,35,29,26,26,20,22,21,26,26,25,21,9,9,6,9,6,8,8,12,11,11,21,14,19,22,23,28,18,16,16,17,16,16,10,11,21,21,21,21,17,17,20,9,24,24,22,25,8,9,5,9,14,17,9,9,15,16,17,9,21,18,18,21,52,53,47,44,44,44,47,49,54,54,53,52,37,38,38,36,44,44,44,43,50,45,47,48,41,41,41,41,48,48,48,46,40,40,27,29,42,40,40,40,35,34,33,30,45,40,43,45,71,70,71,71,29,24,18,15,9,9,7,5,7,23,22,21,28,31,32,30,29,7,6,42,38,41,30,33,29,28,30,34,46,50,44,24,24,24,24,25,25,25,25,45,45,45,45,55,55,55,55,20,20,20,20,60,60,60,60,15,15,15,15,25,25,25,25,55,55,55,55,55,55,55,55,25,25,25,25,40,40,40,40,55,55,55,55,25,25,25,25,25,25,25,25,45,45,45,45,55,55,55,55,15,15,15,15,15,15,15,15,55,55,55,55,55,55,55,55,41,41,41,41,
