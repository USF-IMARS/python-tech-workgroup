# %%
# Import libraries
import os

# %%
# Set paths
path_in='/Users/imars_mbp/server/remote_imars-objects/gom/L2_MODA_r2018/OC'
path_out='Users/imars_mbp/server/remote_imars-objects/wfs/L3_1D_MODA_pytest/OC'

# %%
# Retrieve filelist
basename = os.path.basename(path_in)
print(basename)

files = os.listdir(path_in)
# Out:
# OC
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_55/1281310840.py in <module>
#       3 print(basename)
#       4
# ----> 5 files = os.listdir(path_in)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/imars_mbp/server/remote_imars-objects/gom/L2_MODA_r2018/OC'

# %%
# python comments start with `#`

def my_func():
    """
    Three quotes can be used to create a long comment.
    These triple-quoted things are called docstrings.
    Docstrings do more than just comment though.
    """
    print('this is my func')
