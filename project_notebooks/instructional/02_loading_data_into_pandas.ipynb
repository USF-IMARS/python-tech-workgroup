# %% [markdown]
# # Using pandas dataframes
# This notebook demonstrates how to load data into a pandas dataframe and do basic operations with the dataframe data.

# %% [markdown]
# ## Loading BB3 Cruise data into a pandas df

# %%
# === using `import ... as ...`
# you can import pandas as usual
import pandas
# and use it
print(f"pandas.__version: {pandas.__version__}")

# but people often give pandas another name - `pd` when imported
# to do this you can use `import ... as ...`
import pandas as pd
# now we can make the same code more succinct
print(f"pd.__version__: {pd.__version__}")

# pd and pandas are exactly the same *object*.
print("pd =?= pandas")
print(f"{pd == pandas}")

# if we add something to the pd object
pd.my_randomly_named_attribute = "This is Tylar's special string object"
# the two objects are still equal
print(f"Did adding the attribute change `pd` but not `pandas`? {pd == pandas}")
# we can use the attribute we put on `pd` on the `pandas`
print(f"pandas.my_randomly_named_attribute: {pandas.my_randomly_named_attribute}")

# you can even import it again with a different name
import pandas as whatever_i_feel_like
print(f"whatever_i_feel_like.__version__: {whatever_i_feel_like.__version__}")
# and the new import is still the exact same object as `pd` and `pandas`
print(f"whatever_i_feel_like.my_randomly_named_attribute: {pandas.my_randomly_named_attribute}")
# You can get creative with this but... please don't.
# Stick to the original name or common usages like `pandas as pd`
# Another common one is `numpy as np`
import numpy as np
print(f"np.__version__: {np.__version__}")
# and xarray
import xarray as xr
print(f"xr.__version__: {xr.__version__}")
# Out:
# pandas.__version: 1.3.3
# pd.__version__: 1.3.3
# pd =?= pandas
# True
# Did adding the attribute change `pd` but not `pandas`? True
# pandas.my_randomly_named_attribute: This is Tylar's special string object
# whatever_i_feel_like.__version__: 1.3.3
# whatever_i_feel_like.my_randomly_named_attribute: This is Tylar's special string object
# np.__version__: 1.21.2
# /srv/conda/envs/notebook/lib/python3.7/site-packages/xarray/backends/cfgrib_.py:28: UserWarning: Failed to load cfgrib - most likely there is a problem accessing the ecCodes library. Try `import cfgrib` to get the full error message
#   "Failed to load cfgrib - most likely there is a problem accessing the ecCodes library. "
# xr.__version__: 0.19.0

# %%
pip install "xarray[io]"
# Out:
# Requirement already satisfied: xarray[io] in /srv/conda/envs/notebook/lib/python3.7/site-packages (0.19.0)
# Requirement already satisfied: setuptools>=40.4 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from xarray[io]) (58.2.0)
# Requirement already satisfied: numpy>=1.17 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from xarray[io]) (1.21.2)
# Requirement already satisfied: pandas>=1.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from xarray[io]) (1.3.3)
# Collecting netCDF4
#   Downloading netCDF4-1.5.7-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 4.7 MB/s eta 0:00:01
# Collecting cfgrib
#   Downloading cfgrib-0.9.9.1-py3-none-any.whl (43 kB)
#      |████████████████████████████████| 43 kB 2.9 MB/s  eta 0:00:01
# Collecting fsspec
#   Downloading fsspec-2021.10.1-py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 73.5 MB/s eta 0:00:01
# Collecting rasterio
#   Downloading rasterio-1.2.10-cp37-cp37m-manylinux1_x86_64.whl (19.3 MB)
#      |████████████████████████████████| 19.3 MB 41.7 MB/s eta 0:00:01
# Collecting cftime
#   Downloading cftime-1.5.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (220 kB)
#      |████████████████████████████████| 220 kB 51.8 MB/s eta 0:00:01
# Collecting pydap
#   Downloading Pydap-3.2.2-py3-none-any.whl (2.3 MB)
#      |████████████████████████████████| 2.3 MB 38.0 MB/s eta 0:00:01
# Requirement already satisfied: scipy in /srv/conda/envs/notebook/lib/python3.7/site-packages (from xarray[io]) (1.7.1)
# Collecting zarr
#   Downloading zarr-2.10.1-py3-none-any.whl (146 kB)
#      |████████████████████████████████| 146 kB 49.3 MB/s eta 0:00:01
# Collecting pooch
#   Downloading pooch-1.5.2-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 7.8 MB/s  eta 0:00:01
# Collecting h5netcdf
#   Downloading h5netcdf-0.11.0-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: python-dateutil>=2.7.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas>=1.0->xarray[io]) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas>=1.0->xarray[io]) (2021.3)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas>=1.0->xarray[io]) (1.16.0)
# Requirement already satisfied: attrs>=19.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from cfgrib->xarray[io]) (21.2.0)
# Requirement already satisfied: click in /srv/conda/envs/notebook/lib/python3.7/site-packages (from cfgrib->xarray[io]) (8.0.3)
# Collecting eccodes>=0.9.8
#   Downloading eccodes-1.3.3.tar.gz (59 kB)
#      |████████████████████████████████| 59 kB 7.9 MB/s  eta 0:00:01
# Requirement already satisfied: cffi in /srv/conda/envs/notebook/lib/python3.7/site-packages (from eccodes>=0.9.8->cfgrib->xarray[io]) (1.14.6)
# Collecting findlibs
#   Downloading findlibs-0.0.2.tar.gz (6.2 kB)
# Requirement already satisfied: pycparser in /srv/conda/envs/notebook/lib/python3.7/site-packages (from cffi->eccodes>=0.9.8->cfgrib->xarray[io]) (2.20)
# Requirement already satisfied: importlib-metadata in /srv/conda/envs/notebook/lib/python3.7/site-packages (from click->cfgrib->xarray[io]) (4.8.1)
# Collecting h5py
#   Downloading h5py-3.4.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (4.1 MB)
#      |████████████████████████████████| 4.1 MB 53.5 MB/s eta 0:00:01
# Collecting cached-property
#   Downloading cached_property-1.5.2-py2.py3-none-any.whl (7.6 kB)
# Requirement already satisfied: typing-extensions>=3.6.4 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from importlib-metadata->click->cfgrib->xarray[io]) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from importlib-metadata->click->cfgrib->xarray[io]) (3.6.0)
# Collecting appdirs
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: requests in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pooch->xarray[io]) (2.26.0)
# Requirement already satisfied: packaging in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pooch->xarray[io]) (21.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from packaging->pooch->xarray[io]) (2.4.7)
# Requirement already satisfied: Jinja2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pydap->xarray[io]) (3.0.1)
# Requirement already satisfied: beautifulsoup4 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pydap->xarray[io]) (4.10.0)
# Collecting Webob
#   Downloading WebOb-1.8.7-py2.py3-none-any.whl (114 kB)
#      |████████████████████████████████| 114 kB 59.6 MB/s eta 0:00:01
# Collecting docopt
#   Downloading docopt-0.6.2.tar.gz (25 kB)
# Requirement already satisfied: soupsieve>1.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from beautifulsoup4->pydap->xarray[io]) (2.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from Jinja2->pydap->xarray[io]) (2.0.1)
# Collecting affine
#   Downloading affine-2.3.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: certifi in /srv/conda/envs/notebook/lib/python3.7/site-packages (from rasterio->xarray[io]) (2021.5.30)
# Collecting click-plugins
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Collecting cligj>=0.5
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Collecting snuggs>=1.4.1
#   Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests->pooch->xarray[io]) (2.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests->pooch->xarray[io]) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests->pooch->xarray[io]) (3.1)
# Collecting fasteners
#   Downloading fasteners-0.16.3-py2.py3-none-any.whl (28 kB)
# Collecting numcodecs>=0.6.4
#   Downloading numcodecs-0.9.1-cp37-cp37m-manylinux2010_x86_64.whl (6.2 MB)
#      |████████████████████████████████| 6.2 MB 29.7 MB/s eta 0:00:01
# Collecting asciitree
#   Downloading asciitree-0.3.3.tar.gz (4.0 kB)
# Building wheels for collected packages: eccodes, findlibs, docopt, asciitree
#   Building wheel for eccodes (setup.py) ... done
#   Created wheel for eccodes: filename=eccodes-1.3.3-py3-none-any.whl size=47968 sha256=aa5aa563c2c8471287fe80016be62d1f8a1d3ae938a6b35c7e287bd07c5bc0c6
#   Stored in directory: /home/jovyan/.cache/pip/wheels/53/0b/0b/b029dc9ed4198e34fadc68c3efe35a4de1937889e0e675f792
#   Building wheel for findlibs (setup.py) ... done
#   Created wheel for findlibs: filename=findlibs-0.0.2-py3-none-any.whl size=6559 sha256=80bee9534458aba0aaf24305ebe001e750d771bdf2649d952e0c0e5a75f836a5
#   Stored in directory: /home/jovyan/.cache/pip/wheels/34/e9/92/2a09d5a307252d22fb8d99b13685144b0419d98c36dba7b1c0
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13724 sha256=50a2a4b3c5bb4d8f647cd30d66f197969a8fb11ab1cd2cd97abf378ef034fb7a
#   Stored in directory: /home/jovyan/.cache/pip/wheels/72/b0/3f/1d95f96ff986c7dfffe46ce2be4062f38ebd04b506c77c81b9
#   Building wheel for asciitree (setup.py) ... done
#   Created wheel for asciitree: filename=asciitree-0.3.3-py3-none-any.whl size=5051 sha256=a20cd19c65bf5c5bac5b95d447ea0ad8d23d55639ddc893e7eddb9259e485de7
#   Stored in directory: /home/jovyan/.cache/pip/wheels/12/1c/38/0def51e15add93bff3f4bf9c248b94db0839b980b8535e72a0
# Successfully built eccodes findlibs docopt asciitree
# Installing collected packages: findlibs, cached-property, Webob, snuggs, numcodecs, h5py, fasteners, eccodes, docopt, cligj, click-plugins, cftime, asciitree, appdirs, affine, zarr, rasterio, pydap, pooch, netCDF4, h5netcdf, fsspec, cfgrib
# Successfully installed Webob-1.8.7 affine-2.3.0 appdirs-1.4.4 asciitree-0.3.3 cached-property-1.5.2 cfgrib-0.9.9.1 cftime-1.5.1 click-plugins-1.1.1 cligj-0.7.2 docopt-0.6.2 eccodes-1.3.3 fasteners-0.16.3 findlibs-0.0.2 fsspec-2021.10.1 h5netcdf-0.11.0 h5py-3.4.0 netCDF4-1.5.7 numcodecs-0.9.1 pooch-1.5.2 pydap-3.2.2 rasterio-1.2.10 snuggs-1.4.7 zarr-2.10.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# Loading Sat data into pandas (is df the right data structure for this?)
import os

import pandas
FILEPATH = "../../data/WS19266_BB3.raw"

# read the tab-separated-values file (`.raw` = `.tsv`)
bb3_df = pandas.read_csv(
    FILEPATH, 
    sep='\t',
    on_bad_lines='skip',  # default is 'error'. can also use 'warn' and 'skip'
    # usecols=["date","time","470nm", "470nm_data","532nm", "532nm_data", "650nm", "650nm_data", "mystery_column"],
    skiprows=1
)

# now you can use the pandas dataframe
SEPARATOR = "="*302  # this creates big string like `=====================` with 302 `=` characters
print(bb3_df.describe())
print(SEPARATOR)
print(bb3_df.info())
print(SEPARATOR)
print(bb3_df)
# Out:
#                 470          2153           532          2043           650  \
# count  3.090500e+04  3.078400e+04  3.063000e+04  3.047700e+04  3.027000e+04
# mean   1.333423e+03  3.012149e+03  1.561360e+03  1.326214e+03  9.365565e+02
# std    5.442526e+04  2.408126e+05  6.211511e+04  3.077109e+04  3.776643e+04
# min    0.000000e+00 -2.680000e+02  0.000000e+00 -2.049000e+03  0.000000e+00
# 25%    4.700000e+02  1.260000e+02  5.320000e+02  1.510000e+02  6.500000e+02
# 50%    4.700000e+02  3.050000e+02  5.320000e+02  3.850000e+02  6.500000e+02
# 75%    4.700000e+02  1.040000e+03  5.320000e+02  1.106000e+03  6.500000e+02
# max    4.704130e+06  4.130413e+07  5.324130e+06  4.130130e+06  6.503842e+06
#
#                4130           536
# count  3.006100e+04  29786.000000
# mean   1.918062e+03    528.212348
# std    3.476398e+04    599.449778
# min   -2.670000e+02    -65.000000
# 25%    1.820000e+02    517.000000
# 50%    5.220000e+02    521.000000
# 75%    3.761000e+03    524.000000
# max    4.134130e+06  52521.000000
# ==============================================================================================================================================================================================================================================================================================================
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31073 entries, 0 to 31072
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   07/29/19  31056 non-null  object
#  1   12:06:15  31007 non-null  object
#  2   470       30905 non-null  float64
#  3   2153      30784 non-null  float64
#  4   532       30630 non-null  float64
#  5   2043      30477 non-null  float64
#  6   650       30270 non-null  float64
#  7   4130      30061 non-null  float64
#  8   536       29786 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.1+ MB
# None
# ==============================================================================================================================================================================================================================================================================================================
#        07/29/19  12:06:15    470    2153    532    2043    650    4130    536
# 0      07/29/19  12:06:16  470.0  2151.0  532.0  2034.0  650.0  4130.0  536.0
# 1      07/29/19  12:06:17  470.0  2121.0  532.0  1994.0  650.0  4130.0  535.0
# 2      07/29/19  12:06:18  470.0  2119.0  532.0  1992.0  650.0  4130.0  535.0
# 3      07/29/19  12:06:19  470.0  2117.0  532.0  1991.0  650.0  4130.0  535.0
# 4      07/29/19  12:06:20  470.0  2115.0  532.0  1993.0  650.0  4130.0  535.0
# ...         ...       ...    ...     ...    ...     ...    ...     ...    ...
# 31068  09/29/19  05:10:20  470.0  2045.0  532.0  1537.0  650.0  4130.0  519.0
# 31069  09/29/19  05:10:21  470.0  1405.0  532.0  1480.0  650.0  4130.0  519.0
# 31070  09/29/19  17:36:11  470.0   120.0  532.0    87.0  650.0   853.0  527.0
# 31071  09/29/19  17:36:12  470.0   121.0  532.0    79.0  650.0   847.0  526.0
# 31072       etx       NaN    NaN     NaN    NaN     NaN    NaN     NaN    NaN
#
# [31073 rows x 9 columns]

# %% [markdown]
# ## Loading sat image data into pandas

# %%
import pandas
FILEPATH =  "../../data/MODA_OC_py_data/A2007143182500.L2_LAC_OC.x.nc"

# The xarray library handles arbitrary-dimensional netCDF data, and retains metadata. 
# Xarray provides a simple method of opening netCDF files, and converting them to pandas dataframes.
import xarray

# create an xarray.Dataset from `.nc` file
img_dataset = xarray.open_dataset(FILEPATH)

# Here we use `display()` instead of `print()` to get a prettier output.
# (You can't do this outside of a jupyter notebook.)
from IPython.display import display
display(img_dataset)

# but the xr.DataSet breaks when we try to convert it to a dataframe.
# uncomment the next line and try it yourself:
# img_df = img_dataset.to_dataframe()  # throws `ValueError: no valid index for a 0-dimensional object`

# === convert the `xr.Dataset` to a `pandas.DataFrame`
# this file has a hierarchy of groups so it is more complicated than just using
# `img_dataset.to_dataframe()` as usual.
# [SO q/a ref](https://stackoverflow.com/a/54813257/1483986)
# Out:
# <xarray.Dataset>
# Dimensions:  ()
# Data variables:
#     *empty*
# Attributes: (12/50)
#     title:                             HMODISA Level-2 Data
#     product_name:                      A2007143182500.L2_LAC_OC.nc
#     processing_version:                2018.0
#     equatorCrossingLongitude:          96.08638
#     orbit_number:                      26876
#     history:                           l2gen par=/data3/sdpsoper/vdc/vpu6/wor...
#     ...                                ...
#     geospatial_lon_max:                -75.57883
#     geospatial_lon_min:                -90.01822
#     startDirection:                    Ascending
#     endDirection:                      Ascending
#     day_night_flag:                    Day
#     earth_sun_distance_correction:     0.9754039645195007

# %%
# !FILEPATH="../../data/MODA_OC_py_data/A2007143182500.L2_LAC_OC.x.nc"
# !ncdump -h $FILEPATH
# Out:
# /bin/bash: ncdump: command not found

# %%
NC_GROUP_TO_OPEN = "TODO: PUT_THE_GROUP_HERE"  # get this using bash `ncdump -h` or similar
xr.open_dataset(FILEPATH, group=NC_GROUP_TO_OPEN)

# img_df = img_dataset.to_dataframe()

# now you can use the pandas dataframe
# print(img_df.describe())
# print("="*302)

# print(img_df.variables)
# print(img_df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /srv/conda/envs/notebook/lib/python3.7/site-packages/xarray/backends/netCDF4_.py in _nc4_require_group(ds, group, mode, create_group)
#     177             try:
# --> 178                 ds = ds.groups[key]
#     179             except KeyError as e:
#
# KeyError: 'TODO: PUT_THE_GROUP_HERE'
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# /tmp/ipykernel_217/1419714287.py in <module>
#       1 NC_GROUP_TO_OPEN = "TODO: PUT_THE_GROUP_HERE"  # get this using bash `ncdump -h` or similar
# ----> 2 xr.open_dataset(FILEPATH, group=NC_GROUP_TO_OPEN)
#       3
#       4 # img_df = img_dataset.to_dataframe()
#       5
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/xarray/backends/api.py in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, backend_kwargs, *args, **kwargs)
#     499         drop_variables=drop_variables,
#     500         **decoders,
# --> 501         **kwargs,
#     502     )
#     503     ds = _dataset_from_backend_dataset(
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/xarray/backends/netCDF4_.py in open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta, group, mode, format, clobber, diskless, persist, lock, autoclose)
#     558             persist=persist,
#     559             lock=lock,
# --> 560             autoclose=autoclose,
#     561         )
#     562
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/xarray/backends/netCDF4_.py in open(cls, filename, mode, format, group, clobber, diskless, persist, lock, lock_maker, autoclose)
#     378             netCDF4.Dataset, filename, mode=mode, kwargs=kwargs
#     379         )
# --> 380         return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)
#     381
#     382     def _acquire(self, needs_lock=True):
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/xarray/backends/netCDF4_.py in __init__(self, manager, group, mode, lock, autoclose)
#     326         self._group = group
#     327         self._mode = mode
# --> 328         self.format = self.ds.data_model
#     329         self._filename = self.ds.filepath()
#     330         self.is_remote = is_remote_uri(self._filename)
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/xarray/backends/netCDF4_.py in ds(self)
#     387     @property
#     388     def ds(self):
# --> 389         return self._acquire()
#     390
#     391     def open_store_variable(self, name, var):
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/xarray/backends/netCDF4_.py in _acquire(self, needs_lock)
#     382     def _acquire(self, needs_lock=True):
#     383         with self._manager.acquire_context(needs_lock) as root:
# --> 384             ds = _nc4_require_group(root, self._group, self._mode)
#     385         return ds
#     386
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/xarray/backends/netCDF4_.py in _nc4_require_group(ds, group, mode, create_group)
#     182                 else:
#     183                     # wrap error to provide slightly more helpful message
# --> 184                     raise OSError(f"group not found: {key}", e)
#     185         return ds
#     186
#
# OSError: [Errno group not found: TODO: PUT_THE_GROUP_HERE] 'TODO: PUT_THE_GROUP_HERE'
